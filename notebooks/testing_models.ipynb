# %% [markdown]
# # TESTING MODELS

# %%
# Loading libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Load data

df = pd.read_csv(r'C:\Users\mar27\OneDrive\Documentos\GitHub\airbnb-project\data\processed\engineered_listing.csv')

# %%
# First look at the data

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 100)
df.head(3)
# Out:
#        id  price_R                                               name  host_id  latitude  \
# 0   17878    310.0  Very Nice 2Br in Copacabana w. balcony, fast WiFi    68997 -22.96599
# 1  220377    220.0                   Suíte Casal (banheiro privativo)  1142424 -22.92880
# 2   25026    203.0          Beautiful Modern Decorated Studio in Copa   102840 -22.97735
#
#    longitude        room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  -43.17940  Entire home/apt  52.70               5                319  2024-06-08
# 1  -43.24046     Private room  37.40               1                  5  2024-03-28
# 2  -43.19105  Entire home/apt  34.51               2                291  2024-06-02
#
#    availability_365  number_of_reviews_ltm neighbourhood_cleansed host_response_time  \
# 0               274                     23             Copacabana     within an hour
# 1               283                      1                 Tijuca     within an hour
# 2               241                     23             Copacabana     within an hour
#
#    host_response_rate host_is_superhost host_identity_verified  accommodates  \
# 0               100.0                 t                      t             5
# 1               100.0                 f                      t             2
# 2               100.0                 t                      t             3
#
#    review_scores_rating  review_scores_cleanliness  review_scores_location  \
# 0                  4.71                       4.64                    4.77
# 1                  5.00                       5.00                    4.80
# 2                  4.73                       4.79                    4.84
#
#    review_scores_accuracy  review_scores_communication  review_scores_checkin  \
# 0                    4.77                         4.91                   4.84
# 1                    5.00                         4.80                   5.00
# 2                    4.71                         4.92                   4.82
#
#    review_scores_value                property_type  host_acceptance_rate  maximum_nights  \
# 0                 4.67                 Entire condo                 100.0              28
# 1                 5.00  Private room in rental unit                  47.0             365
# 2                 4.62           Entire rental unit                  82.0              60
#
#                            listing_url  region  distance_to_cristo_redentor  \
# 0   https://www.airbnb.com/rooms/17878     128                     3.548799
# 1  https://www.airbnb.com/rooms/220377     113                     4.001240
# 2   https://www.airbnb.com/rooms/25026     142                     3.460324
#
#    distance_to_pan_de_azucar  distance_to_copacabana_beach  distance_to_ipanema_beach  \
# 0                   3.134953                      0.636423                   3.250991
# 1                   8.994189                      7.596707                   7.148052
# 2                   4.859741                      1.141865                   1.557646
#
#    distance_to_botanical_garden
# 0                      5.100976
# 1                      4.444290
# 2                      4.059350

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34663 entries, 0 to 34662
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            34663 non-null  int64
#  1   price_R                       33691 non-null  float64
#  2   name                          34663 non-null  object
#  3   host_id                       34663 non-null  int64
#  4   latitude                      34663 non-null  float64
#  5   longitude                     34663 non-null  float64
#  6   room_type                     34663 non-null  object
#  7   price                         33691 non-null  float64
#  8   minimum_nights                34663 non-null  int64
#  9   number_of_reviews             34663 non-null  int64
#  10  last_review                   26218 non-null  object
#  11  availability_365              34663 non-null  int64
#  12  number_of_reviews_ltm         34663 non-null  int64
#  13  neighbourhood_cleansed        34663 non-null  object
#  14  host_response_time            28878 non-null  object
#  15  host_response_rate            28878 non-null  float64
#  16  host_is_superhost             33795 non-null  object
#  17  host_identity_verified        34663 non-null  object
#  18  accommodates                  34663 non-null  int64
#  19  review_scores_rating          26218 non-null  float64
#  20  review_scores_cleanliness     26209 non-null  float64
#  21  review_scores_location        26209 non-null  float64
#  22  review_scores_accuracy        26209 non-null  float64
#  23  review_scores_communication   26209 non-null  float64
#  24  review_scores_checkin         26209 non-null  float64
#  25  review_scores_value           26207 non-null  float64
#  26  property_type                 34663 non-null  object
#  27  host_acceptance_rate          31088 non-null  float64
#  28  maximum_nights                34663 non-null  int64
#  29  listing_url                   34663 non-null  object
#  30  region                        34663 non-null  int64
#  31  distance_to_cristo_redentor   34663 non-null  float64
#  32  distance_to_pan_de_azucar     34663 non-null  float64
#  33  distance_to_copacabana_beach  34663 non-null  float64
#  34  distance_to_ipanema_beach     34663 non-null  float64
#  35  distance_to_botanical_garden  34663 non-null  float64
# dtypes: float64(18), int64(9), object(9)
# memory usage: 9.5+ MB

# %%
df.isna().sum()[(df.isna().sum()) > 0]
# Out:
# price_R                         616
# host_response_time             2715
# host_response_rate             2715
# host_is_superhost               737
# review_scores_cleanliness         9
# review_scores_location            9
# review_scores_accuracy            9
# review_scores_communication       9
# review_scores_checkin             9
# review_scores_value              11
# host_acceptance_rate            970
# dtype: int64

# %%
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# ## Handling missing values

# %% [markdown]
# ### Price and Price_R

# %%
df = df.drop(columns='price_R')

# %%
df[df['price'].isna()]
# Out:
#                         id                                               name    host_id  \
# 59                  106372                         Carnaval & Rock in Rio !!!     551316
# 78                  132832                VISTA PRAIA COPA - Excelente Quarto     652627
# 93                  291290                      Apartment in Copacabana / RIO     402478
# 137                 321061  Between three beaches Copacabana Ipanema Arpoador    1644610
# 319                 819354                               ipanema prudente 108    4307081
# ...                    ...                                                ...        ...
# 34198  1178180381253918676                       Apartamento para Rock In Rio   42623590
# 34211  1178402215330843690  Penthouse w/ Private Pool. Wonderful and Spacious  582706037
# 34455  1183484341504966297                            Apartamento confortável  503593469
# 34529  1182502102388486352                       Apt quarto e sala (completo)  230685321
# 34632  1186845135211921432                                         Flamboyant  436154441
#
#         latitude  longitude        room_type  price  minimum_nights  number_of_reviews  \
# 59    -23.007440 -43.430450  Entire home/apt    NaN               4                  9
# 78    -22.982820 -43.189350     Private room    NaN               2                  4
# 93    -22.975660 -43.188930  Entire home/apt    NaN               3                  8
# 137   -22.984125 -43.190884  Entire home/apt    NaN               2                 30
# 319   -22.986120 -43.205640     Private room    NaN               1                  1
# ...          ...        ...              ...    ...             ...                ...
# 34198 -22.962850 -43.390640  Entire home/apt    NaN               2                  0
# 34211 -23.009320 -43.370550  Entire home/apt    NaN               2                  0
# 34455 -22.944612 -43.356948  Entire home/apt    NaN               1                  0
# 34529 -22.963513 -43.400637  Entire home/apt    NaN               3                  0
# 34632 -22.963571 -43.406024  Entire home/apt    NaN               1                  0
#
#       last_review  availability_365  number_of_reviews_ltm   neighbourhood_cleansed  \
# 59     2022-09-11               362                      0          Barra da Tijuca
# 78     2024-05-15                 4                      1               Copacabana
# 93     2024-05-07                 0                      4               Copacabana
# 137    2024-06-05                 0                      8               Copacabana
# 319    2023-03-05               365                      0                  Ipanema
# ...           ...               ...                    ...                      ...
# 34198         NaT                 9                      0              Jacarepaguá
# 34211         NaT               362                      0          Barra da Tijuca
# 34455         NaT               266                      0  Freguesia (Jacarepaguá)
# 34529         NaT               175                      0              Jacarepaguá
# 34632         NaT               260                      0              Jacarepaguá
#
#        host_response_time  host_response_rate host_is_superhost host_identity_verified  \
# 59                    NaN                 NaN                 f                      f
# 78           within a day                90.0                 f                      t
# 93     within a few hours               100.0                 f                      t
# 137        within an hour               100.0                 t                      t
# 319        within an hour                96.0                 t                      t
# ...                   ...                 ...               ...                    ...
# 34198      within an hour               100.0                 f                      t
# 34211                 NaN                 NaN                 f                      t
# 34455      within an hour               100.0                 t                      t
# 34529      within an hour               100.0                 f                      t
# 34632                 NaN                 NaN                 f                      f
#
#        accommodates  review_scores_rating  review_scores_cleanliness  review_scores_location  \
# 59                4                  4.78                       5.00                    4.44
# 78                2                  4.75                       4.33                    5.00
# 93                4                  4.50                       4.50                    5.00
# 137               3                  4.93                       4.97                    4.97
# 319               2                  5.00                       5.00                    5.00
# ...             ...                   ...                        ...                     ...
# 34198             4                   NaN                        NaN                     NaN
# 34211             8                   NaN                        NaN                     NaN
# 34455             3                   NaN                        NaN                     NaN
# 34529             4                   NaN                        NaN                     NaN
# 34632             4                   NaN                        NaN                     NaN
#
#        review_scores_accuracy  review_scores_communication  review_scores_checkin  \
# 59                       4.56                          5.0                    5.0
# 78                       4.67                          5.0                    5.0
# 93                       4.50                          5.0                    5.0
# 137                      5.00                          5.0                    5.0
# 319                      5.00                          5.0                    5.0
# ...                       ...                          ...                    ...
# 34198                     NaN                          NaN                    NaN
# 34211                     NaN                          NaN                    NaN
# 34455                     NaN                          NaN                    NaN
# 34529                     NaN                          NaN                    NaN
# 34632                     NaN                          NaN                    NaN
#
#        review_scores_value                property_type  host_acceptance_rate  maximum_nights  \
# 59                    4.56           Entire rental unit                   NaN            1125
# 78                    4.33  Private room in rental unit                  68.0              15
# 93                    4.13           Entire rental unit                  50.0              30
# 137                   4.90           Entire rental unit                  94.0              30
# 319                   5.00  Private room in rental unit                   9.0            1125
# ...                    ...                          ...                   ...             ...
# 34198                  NaN           Entire rental unit                  50.0               7
# 34211                  NaN           Entire rental unit                   NaN             365
# 34455                  NaN           Entire rental unit                 100.0             365
# 34529                  NaN           Entire rental unit                 100.0              30
# 34632                  NaN           Entire rental unit                   NaN             365
#
#                                             listing_url  region  distance_to_cristo_redentor  \
# 59                  https://www.airbnb.com/rooms/106372     141                    23.348086
# 78                  https://www.airbnb.com/rooms/132832     132                     4.063201
# 93                  https://www.airbnb.com/rooms/291290     129                     3.443426
# 137                 https://www.airbnb.com/rooms/321061     132                     4.107671
# 319                 https://www.airbnb.com/rooms/819354     149                     3.837489
# ...                                                 ...     ...                          ...
# 34198  https://www.airbnb.com/rooms/1178180381253918676     106                    18.484302
# 34211  https://www.airbnb.com/rooms/1178402215330843690      23                    17.584465
# 34455  https://www.airbnb.com/rooms/1183484341504966297     120                    15.017356
# 34529  https://www.airbnb.com/rooms/1182502102388486352      74                    19.510494
# 34632  https://www.airbnb.com/rooms/1186845135211921432      74                    20.061238
#
#        distance_to_pan_de_azucar  distance_to_copacabana_beach  distance_to_ipanema_beach  \
# 59                     28.917606                     25.731065                  23.275640
# 78                      5.160581                      1.494698                   1.555521
# 93                      4.572661                      0.855456                   1.838498
# 137                     5.373687                      1.699396                   1.394064
# 319                     6.630825                      2.923604                   0.273048
# ...                          ...                           ...                        ...
# 34198                  24.148303                     21.359927                  19.199441
# 34211                  23.046659                     19.742917                  17.230007
# 34455                  20.652679                     18.132785                  16.207855
# 34529                  25.174492                     22.379605                  20.207227
# 34632                  25.725246                     22.930452                  20.754575
#
#        distance_to_botanical_garden
# 59                        21.076601
# 78                         4.425299
# 93                         4.223800
# 137                        4.341096
# 319                        3.185948
# ...                             ...
# 34198                     16.536297
# 34211                     15.201507
# 34455                     13.323124
# 34529                     17.557382
# 34632                     18.108541
#
# [972 rows x 35 columns]

# %%
df['price'] = df.groupby(['neighbourhood_cleansed', 'room_type'])['price'].transform(lambda x: x.fillna(x.mean()))

# %%
sum(df['price'].isna())
# Out:
# 11

# %%
df['price'] = df['price'].fillna(df['price'].median())

# %%
sum(df['price'].isna())
# Out:
# 0

# %% [markdown]
# ### Last review

# %%
df[df['last_review'].isna()]
# Out:
#                         id  price_R                                              name    host_id  \
# 18                  247052    414.0                          Christ the Redeemer View    1295841
# 35                   86978    829.0                  Room For a Rent : Rio de Janeiro     476838
# 47                   96478    280.0                APARTAMENT IN BOTAFOGO  BEAUTIFULL     530471
# 48                  273261   5524.0                  Amazing Huge Apartment in Leblon     533566
# 54                   99336    731.0  Casa estilo cabana americana 4 quartos 6 lugares     523251
# ...                    ...      ...                                               ...        ...
# 34658  1187137801637155798    138.0                      Studio Centro Rio de Janeiro   51689400
# 34659  1187154042607981344    800.0                                     Ap Cristo Rio  429712258
# 34660  1187178286136826446    265.0      1BDR 300m from Copacabana Beach | PJ 281/712    6000862
# 34661  1187195682483579137    260.0                         4A - Flat Verano Olímpico   82369585
# 34662  1187208562438757497    250.0                   Apartamento completo no Recreio  357816277
#
#         latitude  longitude        room_type    price  minimum_nights  number_of_reviews  \
# 18    -22.956650 -43.184810  Entire home/apt   70.380               5                  0
# 35    -22.972930 -43.383210     Private room  140.930               1                  0
# 47    -22.946560 -43.181760     Private room   47.600               3                  0
# 48    -22.986320 -43.229360  Entire home/apt  192.355               2                  0
# 54    -22.989230 -43.316570  Entire home/apt  124.270               2                  0
# ...          ...        ...              ...      ...             ...                ...
# 34658 -22.900141 -43.179921  Entire home/apt   23.460               2                  0
# 34659 -22.952882 -43.196048  Entire home/apt  136.000               3                  0
# 34660 -22.963557 -43.175097  Entire home/apt   45.050               1                  0
# 34661 -22.969625 -43.388531  Entire home/apt   44.200               2                  0
# 34662 -23.025702 -43.478011  Entire home/apt   42.500               1                  0
#
#       last_review  availability_365  number_of_reviews_ltm    neighbourhood_cleansed  \
# 18            NaN               118                      0                  Botafogo
# 35            NaN               365                      0               Jacarepaguá
# 47            NaN               344                      0                  Botafogo
# 48            NaN               365                      0                    Leblon
# 54            NaN               223                      0                 Itanhangá
# ...           ...               ...                    ...                       ...
# 34658         NaN               361                      0                    Centro
# 34659         NaN               351                      0                  Botafogo
# 34660         NaN               365                      0                Copacabana
# 34661         NaN                86                      0               Jacarepaguá
# 34662         NaN               258                      0  Recreio dos Bandeirantes
#
#        host_response_time  host_response_rate host_is_superhost host_identity_verified  \
# 18                    NaN                 NaN                 f                      f
# 35                    NaN                 NaN                 f                      t
# 47         within an hour               100.0                 f                      t
# 48                    NaN                 NaN                 f                      f
# 54     within a few hours                82.0                 t                      t
# ...                   ...                 ...               ...                    ...
# 34658      within an hour               100.0                 t                      t
# 34659                 NaN                 NaN                 f                      f
# 34660      within an hour               100.0                 f                      t
# 34661      within an hour               100.0               NaN                      f
# 34662      within an hour               100.0                 f                      t
#
#        accommodates  review_scores_rating  review_scores_cleanliness  review_scores_location  \
# 18                4                   NaN                        NaN                     NaN
# 35                2                   NaN                        NaN                     NaN
# 47                4                   NaN                        NaN                     NaN
# 48                6                   NaN                        NaN                     NaN
# 54                6                   NaN                        NaN                     NaN
# ...             ...                   ...                        ...                     ...
# 34658             2                   NaN                        NaN                     NaN
# 34659             2                   NaN                        NaN                     NaN
# 34660             4                   NaN                        NaN                     NaN
# 34661             2                   NaN                        NaN                     NaN
# 34662             2                   NaN                        NaN                     NaN
#
#        review_scores_accuracy  review_scores_communication  review_scores_checkin  \
# 18                        NaN                          NaN                    NaN
# 35                        NaN                          NaN                    NaN
# 47                        NaN                          NaN                    NaN
# 48                        NaN                          NaN                    NaN
# 54                        NaN                          NaN                    NaN
# ...                       ...                          ...                    ...
# 34658                     NaN                          NaN                    NaN
# 34659                     NaN                          NaN                    NaN
# 34660                     NaN                          NaN                    NaN
# 34661                     NaN                          NaN                    NaN
# 34662                     NaN                          NaN                    NaN
#
#        review_scores_value                property_type  host_acceptance_rate  maximum_nights  \
# 18                     NaN           Entire rental unit                   NaN             730
# 35                     NaN  Private room in rental unit                   NaN              90
# 47                     NaN  Private room in rental unit                   0.0             730
# 48                     NaN           Entire rental unit                   NaN               7
# 54                     NaN                  Entire home                 100.0              30
# ...                    ...                          ...                   ...             ...
# 34658                  NaN           Entire rental unit                 100.0              90
# 34659                  NaN           Entire rental unit                   NaN              28
# 34660                  NaN           Entire rental unit                  99.0              90
# 34661                  NaN           Entire rental unit                 100.0              90
# 34662                  NaN           Entire rental unit                 100.0             365
#
#                                             listing_url  region  distance_to_cristo_redentor  \
# 18                  https://www.airbnb.com/rooms/247052      48                     2.682910
# 35                   https://www.airbnb.com/rooms/86978     127                    17.836707
# 47                   https://www.airbnb.com/rooms/96478      77                     3.002113
# 48                  https://www.airbnb.com/rooms/273261      76                     4.286810
# 54                   https://www.airbnb.com/rooms/99336      46                    11.625526
# ...                                                 ...     ...                          ...
# 34658  https://www.airbnb.com/rooms/1187137801637155798     143                     6.552162
# 34659  https://www.airbnb.com/rooms/1187154042607981344     109                     1.483782
# 34660  https://www.airbnb.com/rooms/1187178286136826446     134                     3.849637
# 34661  https://www.airbnb.com/rooms/1187195682483579137     106                    18.333981
# 34662  https://www.airbnb.com/rooms/1187208562438757497      16                    28.586744
#
#        distance_to_pan_de_azucar  distance_to_copacabana_beach  distance_to_ipanema_beach  \
# 18                      3.151372                      1.628838                   3.639348
# 35                     23.490945                     20.579770                  18.335515
# 47                      2.718859                      2.729099                   4.760217
# 48                      8.665044                      5.115890                   2.559029
# 54                     17.117647                     13.902485                  11.487434
# ...                          ...                           ...                        ...
# 34658                   5.949199                      7.893730                   9.647653
# 34659                   4.199397                      2.472615                   3.555918
# 34660                   2.621954                      1.110118                   3.765366
# 34661                  23.993864                     21.124381                  18.906575
# 34662                  34.128794                     30.880993                  28.377642
#
#        distance_to_botanical_garden
# 18                         4.699410
# 35                        15.779255
# 47                         5.381750
# 48                         2.103875
# 54                         9.267780
# ...                             ...
# 34658                      9.022173
# 34659                      3.758614
# 34660                      5.555645
# 34661                     16.314074
# 34662                     26.280008
#
# [8445 rows x 36 columns]

# %%
df = df.dropna(subset=['last_review'])

# %% [markdown]
# ### Host response time and rate

# %%
df[df['host_response_time'].isna()]
# Out:
#                         id  price_R                                           name    host_id  \
# 42                   89981    221.0             IPANEMA  QUARTO + BANHEIRO PRIVADO     488707
# 43                  272335    147.0            EXCELENTE APARTAMENTO EM COPACABANA    7506316
# 59                  106372      NaN                     Carnaval & Rock in Rio !!!     551316
# 73                  130234    180.0                     excellent studio apartment     641519
# 74                  284762    357.0  10People Ipanema/Copa (Rock, AnoNovo, Feriado    1408960
# ...                    ...      ...                                            ...        ...
# 33774  1166730426796613249    128.0                      Basic - AirbnbinRio - 43b  550745848
# 33938  1166548526428821916    148.0         Confort c. piscina - AirbnbinRio - 24p  550745848
# 33943  1166573730033014899    148.0         Confort c. piscina - AirbnbinRio - 25p  550745848
# 33946  1166611144910691835    113.0                      Basic - AirbnbinRio - 13a  550745848
# 34301  1179692888202969921    350.0     Ipanema - Apto p/2 WiFi AR/C 350m da Praia   94707835
#
#         latitude  longitude        room_type       price  minimum_nights  number_of_reviews  \
# 42    -22.980880 -43.200420     Private room   37.570000               3                167
# 43    -22.962300 -43.173890  Entire home/apt   24.990000               3                345
# 59    -23.007440 -43.430450  Entire home/apt  103.997643               4                  9
# 73    -22.975750 -43.188770  Entire home/apt   30.600000               3                  1
# 74    -22.982770 -43.193600  Entire home/apt   60.690000               3                 10
# ...          ...        ...              ...         ...             ...                ...
# 33774 -22.905771 -43.208549  Entire home/apt   21.760000               1                  2
# 33938 -22.906139 -43.207559  Entire home/apt   25.160000               1                  2
# 33943 -22.906962 -43.208659  Entire home/apt   25.160000               1                  2
# 33946 -22.906896 -43.206879  Entire home/apt   19.210000               1                  1
# 34301 -22.984195 -43.204371  Entire home/apt   59.500000               3                  1
#
#       last_review  availability_365  number_of_reviews_ltm neighbourhood_cleansed  \
# 42     2020-02-27                 3                      0                Ipanema
# 43     2024-06-17               306                     67             Copacabana
# 59     2022-09-11               362                      0        Barra da Tijuca
# 73     2019-02-16                 0                      0             Copacabana
# 74     2024-02-14               363                      2             Copacabana
# ...           ...               ...                    ...                    ...
# 33774  2024-06-14               180                      2           Santo Cristo
# 33938  2024-06-09               167                      2           Santo Cristo
# 33943  2024-06-17               180                      2           Santo Cristo
# 33946  2024-06-03               174                      1           Santo Cristo
# 34301  2024-06-26                93                      1                Ipanema
#
#       host_response_time  host_response_rate host_is_superhost host_identity_verified  \
# 42                   NaN                 NaN                 f                      t
# 43                   NaN                 NaN                 f                      f
# 59                   NaN                 NaN                 f                      f
# 73                   NaN                 NaN                 f                      t
# 74                   NaN                 NaN                 f                      t
# ...                  ...                 ...               ...                    ...
# 33774                NaN                 NaN                 f                      t
# 33938                NaN                 NaN                 f                      t
# 33943                NaN                 NaN                 f                      t
# 33946                NaN                 NaN                 f                      t
# 34301                NaN                 NaN               NaN                      f
#
#        accommodates  review_scores_rating  review_scores_cleanliness  review_scores_location  \
# 42                2                  4.89                       4.99                    4.93
# 43                4                  4.92                       4.88                    4.96
# 59                4                  4.78                       5.00                    4.44
# 73                1                  5.00                       5.00                    5.00
# 74               10                  3.80                       4.60                    4.30
# ...             ...                   ...                        ...                     ...
# 33774             6                  5.00                       5.00                    5.00
# 33938             5                  5.00                       5.00                    5.00
# 33943             5                  5.00                       5.00                    5.00
# 33946             4                  5.00                       5.00                    4.00
# 34301             2                  5.00                       5.00                    5.00
#
#        review_scores_accuracy  review_scores_communication  review_scores_checkin  \
# 42                       4.94                         4.87                   4.96
# 43                       4.92                         4.97                   4.97
# 59                       4.56                         5.00                   5.00
# 73                       5.00                         5.00                   5.00
# 74                       3.50                         4.20                   4.40
# ...                       ...                          ...                    ...
# 33774                    5.00                         5.00                   5.00
# 33938                    5.00                         5.00                   5.00
# 33943                    5.00                         5.00                   5.00
# 33946                    5.00                         5.00                   4.00
# 34301                    5.00                         5.00                   5.00
#
#        review_scores_value                property_type  host_acceptance_rate  maximum_nights  \
# 42                    4.77  Private room in rental unit                   NaN              30
# 43                    4.87           Entire rental unit                   NaN              29
# 59                    4.56           Entire rental unit                   NaN            1125
# 73                    5.00           Entire rental unit                 100.0             720
# 74                    3.60           Entire rental unit                  86.0              15
# ...                    ...                          ...                   ...             ...
# 33774                 5.00           Entire rental unit                   NaN             365
# 33938                 5.00           Entire rental unit                   NaN             365
# 33943                 4.00           Entire rental unit                   NaN             365
# 33946                 5.00           Entire rental unit                   NaN             365
# 34301                 5.00           Entire rental unit                  71.0              28
#
#                                             listing_url  region  distance_to_cristo_redentor  \
# 42                   https://www.airbnb.com/rooms/89981      45                     3.383653
# 43                  https://www.airbnb.com/rooms/272335      33                     3.922760
# 59                  https://www.airbnb.com/rooms/106372     141                    23.348086
# 73                  https://www.airbnb.com/rooms/130234     129                     3.461615
# 74                  https://www.airbnb.com/rooms/284762       0                     3.844006
# ...                                                 ...     ...                          ...
# 33774  https://www.airbnb.com/rooms/1166730426796613249      36                     5.133262
# 33938  https://www.airbnb.com/rooms/1166548526428821916      36                     5.097325
# 33943  https://www.airbnb.com/rooms/1166573730033014899      36                     5.000482
# 33946  https://www.airbnb.com/rooms/1166611144910691835      36                     5.017973
# 34301  https://www.airbnb.com/rooms/1179692888202969921     149                     3.645410
#
#        distance_to_pan_de_azucar  distance_to_copacabana_beach  distance_to_ipanema_beach  \
# 42                      5.850070                      2.159118                   0.535922
# 43                      2.437963                      1.296661                   3.948287
# 59                     28.917606                     25.731065                  23.275640
# 73                      4.566947                      0.848381                   1.847788
# 74                      5.460074                      1.745251                   1.122866
# ...                          ...                           ...                        ...
# 33774                   7.240069                      7.749221                   8.697500
# 33938                   7.136886                      7.675974                   8.652336
# 33943                   7.162265                      7.629216                   8.565765
# 33946                   7.028942                      7.573275                   8.565955
# 34301                   6.395701                      2.696572                   0.035324
#
#        distance_to_botanical_garden
# 42                         3.305716
# 43                         5.691087
# 59                        21.076601
# 73                         4.241968
# 74                         4.025361
# ...                             ...
# 33774                      7.171776
# 33938                      7.163355
# 33943                      7.041936
# 33946                      7.105473
# 34301                      3.154133
#
# [2715 rows x 36 columns]
